# %%
#pip install plotly

# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
co2= pd.read_csv("temperature-anomaly.csv")

# %%
co2.head()
# Out:
#    Entity  Code  Year  Median temperature anomaly from 1961-1990 average  \
# 0  Global   NaN  1850                                             -0.373
# 1  Global   NaN  1851                                             -0.218
# 2  Global   NaN  1852                                             -0.228
# 3  Global   NaN  1853                                             -0.269
# 4  Global   NaN  1854                                             -0.248
#
#    Upper bound (95% CI)  Lower bound (95% CI)
# 0                -0.339                -0.425
# 1                -0.184                -0.274
# 2                -0.196                -0.280
# 3                -0.239                -0.321
# 4                -0.218                -0.301

# %%
co2.shape
# Out:
# (680, 6)

# %%
co2.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Median temperature anomaly from 1961-1990 average',
#        'Upper bound (95% CI)', 'Lower bound (95% CI)'],
#       dtype='object')

# %%
co2 = pd.read_csv("temperature-anomaly.csv")
co2 = px.line(co2, x='Year', y="Median temperature anomaly from 1961-1990 average", color='Entity', title="Co2 and Greenhouse gas emission Plot" )
co2.show()
